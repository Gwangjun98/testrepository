# %%
import tensorflow as tf
import random
# Out:
# C:\Users\jun25\anaconda3\envs\tensorflow_1_3_python_1_6\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\jun25\anaconda3\envs\tensorflow_1_3_python_1_6\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\jun25\anaconda3\envs\tensorflow_1_3_python_1_6\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
x1_data = [73., 93., 89., 96., 73.]
x2_data = [80., 88., 91., 98., 66.]
x3_data = [75., 93., 90., 100., 70.]

y_data = [152., 185., 180., 196., 142.]

# %%
# placeholders for a tensor that will be always fed.
x1 = tf.placeholder(tf.float32) # x1을 변수로써 활용하기 위해 텐서플로로 만들어줌. 
x2 = tf.placeholder(tf.float32) # 트레이닝과 피팅을 위함.
x3 = tf.placeholder(tf.float32) 

Y = tf.placeholder(tf.float32) # y을 변수로써 텐서플로로 만들어줌.

# %%
w1 = tf.Variable(tf.random_normal([1]), name='weight1') #최적의 가중치를 찾기.
w2 = tf.Variable(tf.random_normal([1]), name='weight2')
w3 = tf.Variable(tf.random_normal([1]), name='weight3')
b = tf.Variable(tf.random_normal([1]), name='bias')
# Out:
# WARNING:tensorflow:From C:\Users\jun25\anaconda3\envs\tensorflow_1_3_python_1_6\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
hypothesis = x1 * w1 + x2 * w2 + x3 * w3 + b # 가설 설정

# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize. Need a very small learning rate for this data set
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5) #최적화
train = optimizer.minimize(cost) #트레이닝
# Out:
# WARNING:tensorflow:From C:\Users\jun25\anaconda3\envs\tensorflow_1_3_python_1_6\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
# Launch the graph in a session.
sess = tf.Session() # 세션으로 텐서플로에 흐름 집어넣기
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer()) # 초기화

for step in range(4001): # 4000번 반복
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train], 
                                   feed_dict={x1: x1_data, x2: x2_data, x3: x3_data, Y: y_data})
    if step % 50 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)
# Out:
# 0 Cost:  28141.896
# Prediction:
#  [1.8537257 6.280142  4.074688  4.0478334 6.2449207]
# 50 Cost:  0.45937616
# Prediction:
#  [150.713   185.17735 180.35585 196.01224 142.69446]
# 100 Cost:  0.45122585
# Prediction:
#  [150.72372 185.17001 180.35916 196.0145  142.68494]
# 150 Cost:  0.44327444
# Prediction:
#  [150.73433 185.16275 180.36243 196.01671 142.67552]
# 200 Cost:  0.43554473
# Prediction:
#  [150.74478 185.15558 180.36563 196.0189  142.66626]
# 250 Cost:  0.42803207
# Prediction:
#  [150.7551  185.14854 180.36884 196.02107 142.65714]
# 300 Cost:  0.42070693
# Prediction:
#  [150.76527 185.14159 180.37195 196.02321 142.64812]
# 350 Cost:  0.41358328
# Prediction:
#  [150.7753  185.13469 180.37505 196.02528 142.6392 ]
# 400 Cost:  0.40664524
# Prediction:
#  [150.78522 185.12793 180.37811 196.02737 142.63043]
# 450 Cost:  0.39988908
# Prediction:
#  [150.795   185.12125 180.3811  196.0294  142.62178]
# 500 Cost:  0.39331773
# Prediction:
# ...

# %%
print('Hello world')
# Out:
# Hello world
